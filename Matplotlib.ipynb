# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadjonArabov/Python-For-Data-Analytics/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40, 50]
y = [20, 30, 70, 10, 50]

plt.plot(x, y)
plt.title("Line Chart")

plt.title("Line Chart")

plt.ylabel('Y-Axis')

plt.xlabel('X-Axis')
plt.show()

# %%
import numpy as np

np.random.seed(20)
data = [np.random.normal(0, std, 100) for std in range(1, 8)]

plt.boxplot(data, vert=True, patch_artist=True,
            boxprops=dict(facecolor='skyblue'),
            medianprops=dict(color='red'))

plt.xlabel('Data Set')
plt.ylabel('Values')
plt.title('Box Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(0)
data = np.random.rand(10, 10)

plt.imshow(data, cmap='viridis', interpolation='nearest')

plt.colorbar()

plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Heatmap')

plt.show()

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

plt.plot(x, y, color='green', linewidth=3, marker='o',
         markersize=15, linestyle='--')

plt.title("Customizing Line Chart")

plt.ylabel('Y-Axis')

plt.xlabel('X-Axis')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

fig = plt.figure(figsize =(7, 5), facecolor='g',
                 edgecolor='b', linewidth=7)

ax = fig.add_axes([1, 1, 1, 1])

ax.plot(x, y)

plt.title("Linear graph", fontsize=25, color="yellow")

plt.ylabel('Y-Axis')
plt.xlabel('X-Axis')

plt.ylim(0, 80)

plt.xticks(x, labels=["one", "two", "three", "four"])

plt.legend(["GFG"])

plt.show()

# %%
from matplotlib.figure import Figure


x = [10, 25, 30, 40]
y = [15, 25, 35, 55]

fig = plt.figure(figsize = (5, 4))
ax = fig.add_axes([1, 1, 1, 1])

ax1 = ax.plot(x, y)
ax2 = ax.plot(y, x)

ax.set_title("Linear Graph")

ax.set_xlabel("X-Axis")
ax.set_ylabel("Y-Axis")

ax.legend(labels = ('line 1', 'line 2'))

# %%
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

fig = plt.figure(figsize =(5, 4))

ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])

ax2 = fig.add_axes([1, 0.1, 0.8, 0.8])

ax1.plot(x, y)
ax2.plot(y, x)

plt.show()

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

plt.figure()

plt.subplot(121)
plt.plot(x, y)

plt.subplot(122)
plt.plot(y, x)

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

axes1 = plt.subplot2grid (
(7, 1), (0, 0), rowspan = 2, colspan = 1)

axes2 = plt.subplot2grid (
(7, 1), (2, 0), rowspan = 2, colspan = 1)

axes1.plot(x, y)
axes2.plot(y, x)

# %%
x = [1, 20, 3, 4]
y = [10, 20, 30, 40]

plt.plot(x, y)
plt.title("Liner Plot")
plt.show()

# %%
plt.scatter(x, y)
plt.title('Scatter Plot')
plt.show()

# %%
x = ['a', 'b', 'c', 'd']
y = [8, 9, 3, 2]
plt.bar(x, y)
plt.title('Bar Chart')
plt.show()

# %%
plt.barh(x, y)
plt.title("Horizantal Bar Chart")
plt.show()

# %%
sizes = [25, 35, 45, 55]
labels = ['A', 'B', 'C', 'D']
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('Pie Char')
plt.show()

# %%
data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 5, 5, 5]
plt.hist(data, bins=4)
plt.title('Histogram')
plt.show()

# %%
data = [2, 34, 12, 23, 45, 17, 8, 7]
plt.boxplot(data)
plt.title('Boxplot')
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [3, 4, 5, 6, 7]
error = [0.2, 0.4, 0.1, 0.7, 0.8]
plt.errorbar(x, y, yerr=error, fmt='o')
plt.title('Error Bar Plt')
plt.show()

# %%
A = [2, 4, 6, 8]
B = [1, 3, 5, 7]
labels = ['x', 'y', 'z', 'e']
plt.bar(labels, A)
plt.bar(labels, B, bottom=A)
plt.title = ("Stacked Bar Char")
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

plt.fill_between(x, y)
plt.show()

# %%
x = [1, 3, 5, 7]
y = [12, 34, 56, 67]
plt.stem(x, y)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [1, 2, 3, 4, 5]
plt.step(x, y)
plt.show()

# %%
import numpy as np

theta = np.linspace(0, 2*np.pi, 100)
r = np.abs(np.sin(theta))
plt.polar(theta, r)
plt.show()

# %%
data = np.random.rand(5, 5)
plt.imshow(data, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(0, 5, 100)
y = np.sin(x)
z = np.cos(x)

ax.plot(x, y, z)
plt.show()
